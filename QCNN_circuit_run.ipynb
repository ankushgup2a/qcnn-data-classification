# %%
# !git clone https://github.com/ankushgup2a/qcnn-data-classification.git
# Out:
# Cloning into 'qcnn-data-classification'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 137 (delta 39), reused 136 (delta 38), pack-reused 0
# Receiving objects: 100% (137/137), 981.46 KiB | 7.98 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# !pip install pennylane
# !pip install emnist
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 15.3 MB 43.0 MB/s
# ...
#      |████████████████████████████████| 145 kB 44.5 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 8.5 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# upload print_circuit.py file
# NOTE: edit the Training.py file and change the iteration to 1 just to quickly see the printed circuit
#from google.colab import files
#uploaded = files.upload()
# Out:
#      <input type="file" id="files-cc912809-8f6f-498f-ace5-0cfe5363a858" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc912809-8f6f-498f-ace5-0cfe5363a858">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Run one of the following commands to either print the circuit with iteration 1 in Training.py 
# or 200 with result.py
#!python ./qcnn-data-classification/QCNN/print_circuit.py
# !python ./qcnn-data-classification/QCNN/result.py
# Out:
# 2022-11-27 13:42:42.531206: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# iteration:  0  cost:  17.142455914743557
# 0: ─╭AmplitudeEmbedding(M0)──U3(-0.45,0.12,-1.50)──╭●──RY(-1.21)─╭X──RY(0.56)─╭●
# 1: ─├AmplitudeEmbedding(M0)────────────────────────│─────────────│────────────│─
# 2: ─├AmplitudeEmbedding(M0)────────────────────────│─────────────│────────────│─
# 3: ─├AmplitudeEmbedding(M0)────────────────────────│─────────────│────────────│─
# 4: ─├AmplitudeEmbedding(M0)────────────────────────│─────────────│────────────│─
# 5: ─├AmplitudeEmbedding(M0)────────────────────────│─────────────│────────────│─
# 6: ─├AmplitudeEmbedding(M0)────────────────────────│─────────────│────────────│─
# 7: ─╰AmplitudeEmbedding(M0)──U3(-0.65,-0.01,-1.23)─╰X──RZ(-0.17)─╰●───────────╰X
#
# ───U3(0.05,0.63,1.15)─────U3(-0.45,0.12,-1.50)──╭●──────────RY(-1.21)─╭X─────────RY(0.56)
# ...
